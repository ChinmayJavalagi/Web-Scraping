# %%
#importing libraries

# from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
#reading thr URL

html_text = requests.get("https://www.flipkart.com/q/best-laptops-under-rs-50000").text
soup = BeautifulSoup(html_text, 'lxml')

# %%
html_text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.79b2e6.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57"
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# dir(soupdata)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_check_markup_is_url',
#  '_decode_markup',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
# ...

# %%
containers = soup.find_all('div', class_ = '_2kHMtA')

# %%
containers
# Out:
# [<div class="_2kHMtA"><a class="_1fQZEK" href="/msi-bravo-15-ryzen-5-hexa-core-amd-r5-5600h-8-gb-512-gb-ssd-windows-11-home-4-graphics-amd-radeon-rx-5500m-144-hz-b5dd-410in-gaming-laptop/p/itm12cedc4da03bc?pid=COMGGHMQVWN6JJGC&amp;lid=LSTCOMGGHMQVWN6JJGCTAUNJV&amp;marketplace=FLIPKART&amp;store=6bo%2Fb5g&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=4b49a869-0a50-41ea-9a29-22ee2fbec0cc.COMGGHMQVWN6JJGC.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=khb1vovl2o0000001670613664697" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="MSI Bravo 15 Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/AMD Radeo..." class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/computer/7/3/l/-original-imagha3pvvc2xuz2.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><in
# ...

# %%
# containers = soupdata.findAll('div', {'class':'_2kHMtA'})
# print(type(containers),len(containers))

# %%
# dir(containers)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort',
#  'source']

# %%
containers[0]
# Out:
# <div class="_2kHMtA"><a class="_1fQZEK" href="/msi-bravo-15-ryzen-5-hexa-core-amd-r5-5600h-8-gb-512-gb-ssd-windows-11-home-4-graphics-amd-radeon-rx-5500m-144-hz-b5dd-410in-gaming-laptop/p/itm12cedc4da03bc?pid=COMGGHMQVWN6JJGC&amp;lid=LSTCOMGGHMQVWN6JJGCTAUNJV&amp;marketplace=FLIPKART&amp;store=6bo%2Fb5g&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=4b49a869-0a50-41ea-9a29-22ee2fbec0cc.COMGGHMQVWN6JJGC.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=khb1vovl2o0000001670613664697" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="MSI Bravo 15 Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/AMD Radeo..." class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/computer/7/3/l/-original-imagha3pvvc2xuz2.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><inp
# ...

# %%
#To extract:
#1.Product name
#2.Current price
#3.MRP
#4.Stars
#5.Ratings
#6.Reviews
#7.Processor
#8.RAM
#9.Harddisk
#10.Image URL


for index, container in enumerate(containers):
#     product_name = container.find('div', class_ = '_4rR01T').text.split('-')[0]
    stars = container.find('div', class_ = '_3LWZlK')
    try:
        print(stars.text)
    except:
        print(stars)
        
    rating = container.find('span', class_ = '_2_R_DZ')
    try:
        print(rating.span.text.split('&')[0])
    except:
        print(rating)
# Out:
# 4.4
# 1,764 Ratings
# 4.2
# 2,977 Ratings
# 4.4
# 2,891 Ratings
# 4.2
# 3,764 Ratings
# 4.3
# 830 Ratings
# 4.2
# 1,557 Ratings
# 4.2
# 154 Ratings
# 4.1
# 141 Ratings
# 4.2
# 229 Ratings
# None
# None
# 4.3
# 1,793 Ratings
# 4.1
# 90 Ratings
# 4.3
# 28 Ratings
# 4.3
# 567 Ratings
# 4.3
# 541 Ratings
# 4.3
# 1,361 Ratings
# 4.2
# 550 Ratings
# 4.3
# 625 Ratings
# 4.3
# 4,360 Ratings
# 4.2
# 32 Ratings
# 3.3
# 3 Ratings
# 4.3
# 1,545 Ratings
# None
# None
# 4.5
# 869 Ratings
